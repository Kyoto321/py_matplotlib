# %% [markdown]
# ### Python Graph/Plotting

# %% [markdown]
# ### Real World Examples
# #### site = https://www.youtube.com/watch?v=0P7QnIQDBJY

# %% [markdown]
# #### Load Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np 
import pandas as pd

# %% [markdown]
# #### Line Graph

# %% [markdown]
# #### Load Gas Prices

# %%
gas = pd.read_csv('gas_prices.csv')

gas
# Out:
#     Year  Australia  Canada  France  Germany  Italy  Japan  Mexico  \
# 0   1990        NaN    1.87    3.63     2.65   4.59   3.16    1.00
# 1   1991       1.96    1.92    3.45     2.90   4.50   3.46    1.30
# 2   1992       1.89    1.73    3.56     3.27   4.53   3.58    1.50
# 3   1993       1.73    1.57    3.41     3.07   3.68   4.16    1.56
# 4   1994       1.84    1.45    3.59     3.52   3.70   4.36    1.48
# 5   1995       1.95    1.53    4.26     3.96   4.00   4.43    1.11
# 6   1996       2.12    1.61    4.41     3.94   4.39   3.64    1.25
# 7   1997       2.05    1.62    4.00     3.53   4.07   3.26    1.47
# 8   1998       1.63    1.38    3.87     3.34   3.84   2.82    1.49
# 9   1999       1.72    1.52    3.85     3.42   3.87   3.27    1.79
# 10  2000       1.94    1.86    3.80     3.45   3.77   3.65    2.01
# 11  2001       1.71    1.72    3.51     3.40   3.57   3.27    2.20
# 12  2002       1.76    1.69    3.62     3.67   3.74   3.15    2.24
# ...

# %%
gas = pd.read_csv('gas_prices.csv')

# Make size bigger
plt.figure(figsize=(8,5))

# To add title
plt.title('Gas Prices over Time (in USD)')


# To construct a line graph a particular country
plt.plot(gas.Year, gas.USA, 'b.-', label='United States')
plt.plot(gas.Year, gas.Canada, 'r.-', label ='Canada')
plt.plot(gas.Year, gas.Australia, 'b.-', label='Australia')
# For two words countries 
plt.plot(gas.Year, gas['South Korea'],'g.-', label='South Korea' )


'''
for country in gas:
    if country != 'Year':
        plt.plot(gas.Year, gas[country], marker='.')  #***solve the label issue later
''' 

'''
countries_to_look_at = ['Australia', 'USA', 'Canada', 'South Korea']
for country in gas:
    if country in countries_to_look_at:
        plt.plot(gas.Year, gas[country], marker='.')
'''

        
# Distance between the x-axis values/to add to list
plt.xticks(gas.Year[::3].tolist()+[2011])

plt.xlabel('Year')
plt.ylabel('US Dollars')

plt.legend()

plt.savefig('Gas_price_figure.png', dpi=300)

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# #### Load Fifa Data

# %%
fifa = pd.read_csv('fifa_data.csv')

fifa.head(25)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %% [markdown]
# #### Histogram

# %%
bins = [30,40,50,60,70,80,90,100]

plt.hist(fifa.Overall, bins=bins, color='r')

plt.xticks(bins)

plt.ylabel('Number of Players')
plt.xlabel('Skill Level')
plt.title('Distribution of Player Skills in FIFA 2018')

plt.show()

# %% [markdown]
# #### Pie Charts

# %%
fifa.head(25)
# Out:
#     Unnamed: 0      ID               Name  Age  \
# 0            0  158023           L. Messi   31
# 1            1   20801  Cristiano Ronaldo   33
# 2            2  190871          Neymar Jr   26
# 3            3  193080             De Gea   27
# 4            4  192985       K. De Bruyne   27
# 5            5  183277          E. Hazard   27
# 6            6  177003          L. Modrić   32
# 7            7  176580          L. Suárez   31
# 8            8  155862       Sergio Ramos   32
# 9            9  200389           J. Oblak   25
# 10          10  188545     R. Lewandowski   29
# 11          11  182521           T. Kroos   28
# 12          12  182493           D. Godín   32
# 13          13  168542        David Silva   32
# 14          14  215914           N. Kanté   27
# 15          15  211110          P. Dybala   24
# 16          16  202126            H. Kane   24
# 17          17  194765       A. Griezmann   27
# 18          18  192448      M. ter Stegen   26
# ...

# %%
# Percentage of pople playing with right foot vs left foot

# %%
#look up the data set
left = fifa.loc[fifa['Preferred Foot'] == 'Left'].count()[0]
right = fifa.loc[fifa['Preferred Foot'] == 'Right'].count()[0]

#plot style
plt.style.use('ggplot')

#labeling both side of the pieChats
labels = ['left', 'right']
colors = ['red', 'blue']

plt.pie([left, right], labels = labels, colors=colors, autopct='%.2f')

plt.title('Foot Preference of FIFA Players')

plt.pie([left, right])
# Out:
# ([<matplotlib.patches.Wedge at 0x7f7c0b7d18d0>,
# ...
#  [Text(0.8207745153900478, 0.7323449971743047, ''),
#   Text(-0.8207745496735903, -0.732344958751076, '')])

# %%
fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]

#plot style
plt.style.use('ggplot')

light = fifa.loc[fifa.Weight < 125].count()[0]
light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 175)].count()[0]
medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 175)].count([0])
heavy = fifa[fifa.Weight >= 200].count([0])

weights = [light, light_medium, medium, medium_heavy, heavy]
labels = ['Under 125', '125-150', '150-175', '175-200', 'Over 200']
explode = (.4, .1, 0, 0, 0.4)

plt.title('Weight Distributions of FIFA Players (in lbs)')

plt.pie(weights, labels=labels, autopct='%.2f %%', pctdistance=0.8, explode=explode)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [27], line 3
#       1 fifa.Weight = [int(x.strip('lbs')) if type(x)==str else x for x in fifa.Weight]
# ----> 3 light = fifa.loc[fifa.Weight < 125].count()[0]
#       4 light_medium = fifa.loc[(fifa.Weight >= 125) & (fifa.Weight < 175)].count()[0]
#       5 medium_heavy = fifa[(fifa.Weight >= 175) & (fifa.Weight < 175)].count([0])
#
# TypeError: '<' not supported between instances of 'list' and 'int'

# %% [markdown]
#  #### Box and Whiskers Chart

# %%
plt.style.use('default')

plt.figure(figsize=(5,8))

barcelona = fifa.loc[fifa.Club == 'FC Barcelona']['Overall']
madrid = fifa.loc[fifa.Club == 'Real Madrid']['Overall']

labels = ['FC Barcelona', 'Real Madrid']

boxes = plt.boxplot([barcelona, madrid], labels=labels, patch_artist=True, medianprops={'linewidth':2}) 

for box in boxes['boxes']:
    # set edge color
    box.set(color='#4286f4', linewidth =2)
    
    # change fill color
box.set(facecolor='#e0e0e0')

plt.title('Professional Football Team Comparison')
plt.ylabel('FIFA Overall Rating')

plt.show()
